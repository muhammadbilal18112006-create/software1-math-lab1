# %% [markdown]
# # Lab 1 - My solutions
# **Basics of numpy and matplotlib**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Muhammad Bilal" # Write your name between the parenthesis
student_id = 2601860 # Change your student ID here
date_returned = "09.03.2026" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display # IPython.display is used to display Markdown text in Jupyter notebooks
import numpy as np # numpy is used for numerical calculations
import matplotlib.pyplot as plt # matplotlib is used for plotting graphics
import labx as mx # Remember to download labx module from OMA assignment !!!

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
x = np.arange(-10, 10, 0.001)

y = mx.lab_1_problem_1(x, student_id)

# plot it
plt.figure()
plt.plot(x, y)
plt.title("Function f(x) for student 2601860")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## My solution for problem 2

# %%
c = 1  # the constant line y = 1

import matplotlib.pyplot as plt

# I prefer to show all views together so it's easy to read and grade.
fig, axes = plt.subplots(3, 1, figsize=(10, 12))

ax = axes[0]
ax.plot(x, y)
ax.axhline(c, color='red', linestyle='--', label='y = 1')
ax.set_title("Overview: f(x) and the line y = 1")
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
ax.grid(True)
ax.legend(loc='upper left')

# 2) Zoomed view – LEFT intersection

ax = axes[1]
ax.plot(x, y)
ax.axhline(c, color='red', linestyle='--', label='y = 1')
ax.set_xlim(-7, -4)   # adjust by eye if needed
ax.set_ylim(0, 5)     # keep the y=1 line clearly visible
ax.set_title("Zoomed view – Left intersection with y = 1")
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
ax.grid(True)

# 3) Zoomed view – RIGHT intersection

ax = axes[2]
ax.plot(x, y)
ax.axhline(c, color='red', linestyle='--', label='y = 1')
ax.set_xlim(2, 5)     # adjust by eye if needed
ax.set_ylim(0, 5)
ax.set_title("Zoomed view – Right intersection with y = 1")
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
ax.grid(True)

plt.tight_layout()
plt.show()
