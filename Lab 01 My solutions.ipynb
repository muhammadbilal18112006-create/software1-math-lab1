# %% [markdown]
# # Lab 1 - My solutions
# **Basics of numpy and matplotlib**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Muhammad Bilal" # Write your name between the parenthesis
student_id = "2601860" # Change your student ID here
date_returned = "09/03/2026" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display # IPython.display is used to display Markdown text in Jupyter notebooks
import numpy as np # numpy is used for numerical calculations
import matplotlib.pyplot as plt # matplotlib is used for plotting graphics
import labx as mx # Remember to download labx module from OMA assignment !!!

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
# x values from -10 to 10, step 0.001
x = np.arange(-10, 10, 0.001)

# get y from the lab function
y = mx.lab_1_problem_1(x, student_id)

# plot it
plt.figure()
plt.plot(x, y)
plt.title("Function f(x) for student 2601860")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       2 x = np.arange(-10, 10, 0.001)
#       4 # get y from the lab function
# ----> 5 y = mx.lab_1_problem_1(x, student_id)
#       7 # plot it
#       8 plt.figure()
#
# File D:\New Python math labs\labx.py:18, in lab_1_problem_1(x, seed)
#      17 def lab_1_problem_1(x, seed = 0):
# ---> 18     p = generate_polynomial(seed, 2)
#      19     return np.polyval(p, x)
#
# File D:\New Python math labs\labx.py:12, in generate_polynomial(seed, order)
#      10 if seed == 0:
#      11     seed = time.time_ns()
# ---> 12 rng = np.random.default_rng(seed)
#      13 roots = rng.random(order)*15 - 7.5  # Generate two random roots
#      14 p = np.round(np.poly(roots), 4)  # Get coefficients of the polynomial
#
# File numpy/random/_generator.pyx:5076, in numpy.random._generator.default_rng()
#
# File numpy/random/_pcg64.pyx:123, in numpy.random._pcg64.PCG64.__init__()
#
# File numpy/random/bit_generator.pyx:536, in numpy.random.bit_generator.BitGenerator.__init__()
#
# File numpy/random/bit_generator.pyx:308, in numpy.random.bit_generator.SeedSequence.__init__()
#
# TypeError: SeedSequence expects int or sequence of ints for entropy not 2601860

# %% [markdown]
# ---
# ## My solution for problem 2
